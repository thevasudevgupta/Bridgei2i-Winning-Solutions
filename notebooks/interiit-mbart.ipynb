# %%
# !cd /content/drive/MyDrive/interiit/ && pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 1.2MB 18.5MB/s
# ...

# %%
cd /content/drive/MyDrive/interiit/src/
# Out:
# /content/drive/MyDrive/interiit/src

# %%
# !python data_utils/dataloader.py
# Out:
# Using custom data configuration default-9aefac9c5c0637cd
# Reusing dataset csv (/root/.cache/huggingface/datasets/csv/default-9aefac9c5c0637cd/0.0.0/2a88c45fed596f9421a2e7f74ab1a3cd012ef75210a5dc1950e8d60ca8d9c66c)
# Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-9aefac9c5c0637cd/0.0.0/2a88c45fed596f9421a2e7f74ab1a3cd012ef75210a5dc1950e8d60ca8d9c66c/cache-71038090b8302a50.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/default-9aefac9c5c0637cd/0.0.0/2a88c45fed596f9421a2e7f74ab1a3cd012ef75210a5dc1950e8d60ca8d9c66c/cache-f03e209a14779014.arrow
#   0% 0/4000 [00:00<?, ?ex/s]2021-03-13 00:19:01.460023: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 100% 4000/4000 [00:02<00:00, 1575.44ex/s]
# 100% 4000/4000 [00:00<00:00, 9179.26ex/s]
